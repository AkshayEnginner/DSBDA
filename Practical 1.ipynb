# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('customer.csv')

# %%
df
# Out:
#      CustomerID  Gender  Age  AnnualSalary(k$)  Spendings(1-100)
# 0           157    Male   37                78                 1
# 1           159    Male   34                78                 1
# 2           201  Female   19               137                 1
# 3             9    Male   64                19                 3
# 4           202  Female   19               137                 3
# ..          ...     ...  ...               ...               ...
# 245         247  Female   69               101                97
# 246          20  Female   35                23                98
# 247         248  Female   70               103                98
# 248          12  Female   35                19                99
# 249         249    Male   70                97                99
#
# [250 rows x 5 columns]

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  AnnualSalary(k$)  Spendings(1-100)
# 0         157    Male   37                78                 1
# 1         159    Male   34                78                 1
# 2         201  Female   19               137                 1
# 3           9    Male   64                19                 3
# 4         202  Female   19               137                 3

# %%
df.tail()
# Out:
#      CustomerID  Gender  Age  AnnualSalary(k$)  Spendings(1-100)
# 245         247  Female   69               101                97
# 246          20  Female   35                23                98
# 247         248  Female   70               103                98
# 248          12  Female   35                19                99
# 249         249    Male   70                97                99

# %%
df.describe()
# Out:
#        CustomerID         Age  AnnualSalary(k$)  Spendings(1-100)
# count  250.000000  250.000000         250.00000        250.000000
# mean   125.500000   39.688000          61.23200         50.268000
# std     72.312977   14.716554          28.37348         27.109553
# min      1.000000   18.000000          15.00000          1.000000
# 25%     63.250000   28.000000          40.00000         31.250000
# 50%    125.500000   36.500000          61.50000         50.000000
# 75%    187.750000   50.000000          78.00000         73.000000
# max    250.000000   70.000000         137.00000         99.000000

# %%
df.shape
# Out:
# (250, 5)

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'AnnualSalary(k$)', 'Spendings(1-100)'], dtype='object')

# %%
df.drop(['Age'],axis=1)
# Out:
#      CustomerID  Gender  AnnualSalary(k$)  Spendings(1-100)
# 0           157    Male                78                 1
# 1           159    Male                78                 1
# 2           201  Female               137                 1
# 3             9    Male                19                 3
# 4           202  Female               137                 3
# ..          ...     ...               ...               ...
# 245         247  Female               101                97
# 246          20  Female                23                98
# 247         248  Female               103                98
# 248          12  Female                19                99
# 249         249    Male                97                99
#
# [250 rows x 4 columns]

# %%
df.values
# Out:
# array([[157, 'Male', 37, 78, 1],
#        [159, 'Male', 34, 78, 1],
#        [201, 'Female', 19, 137, 1],
#        ...,
#        [248, 'Female', 70, 103, 98],
#        [12, 'Female', 35, 19, 99],
#        [249, 'Male', 70, 97, 99]], dtype=object)

# %%
df.dtypes
# Out:
# CustomerID           int64
# Gender              object
# Age                  int64
# AnnualSalary(k$)     int64
# Spendings(1-100)     int64
# dtype: object

# %%
df.iloc[2:8]
# Out:
#    CustomerID  Gender  Age  AnnualSalary(k$)  Spendings(1-100)
# 2         201  Female   19               137                 1
# 3           9    Male   64                19                 3
# 4         202  Female   19               137                 3
# 5          31    Male   60                30                 4
# 6          33    Male   53                33                 4
# 7         203    Male   19               137                 4

# %%
df[df['Age']>50]
# Out:
#      CustomerID  Gender  Age  AnnualSalary(k$)  Spendings(1-100)
# 3             9    Male   64                19                 3
# 5            31    Male   60                30                 4
# 6            33    Male   53                33                 4
# 10          141  Female   57                75                 5
# 25          129    Male   59                71                11
# 29          175  Female   52                88                13
# 31           11    Male   67                19                14
# 32           25  Female   54                28                14
# 34          179    Male   59                93                14
# 36           13  Female   58                20                15
# 37          177    Male   58                88                15
# 53          187  Female   54               101                24
# 60           19    Male   52                23                29
# ...

# %%
df[df['Gender'].isin(['Female'])]
# Out:
#      CustomerID  Gender  Age  AnnualSalary(k$)  Spendings(1-100)
# 2           201  Female   19               137                 1
# 4           202  Female   19               137                 3
# 8            23  Female   46                25                 5
# 10          141  Female   57                75                 5
# 13            3  Female   20                16                 6
# ..          ...     ...  ...               ...               ...
# 241         168  Female   33                86                95
# 245         247  Female   69               101                97
# 246          20  Female   35                23                98
# 247         248  Female   70               103                98
# 248          12  Female   35                19                99
#
# [139 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# CustomerID          0
# Gender              0
# Age                 0
# AnnualSalary(k$)    0
# Spendings(1-100)    0
# dtype: int64

# %%
df.dropna()
# Out:
#      CustomerID  Gender  Age  AnnualSalary(k$)  Spendings(1-100)
# 0           157    Male   37                78                 1
# 1           159    Male   34                78                 1
# 2           201  Female   19               137                 1
# 3             9    Male   64                19                 3
# 4           202  Female   19               137                 3
# ..          ...     ...  ...               ...               ...
# 245         247  Female   69               101                97
# 246          20  Female   35                23                98
# 247         248  Female   70               103                98
# 248          12  Female   35                19                99
# 249         249    Male   70                97                99
#
# [250 rows x 5 columns]

# %%
df['new column / netsalry'] = df['AnnualSalary(k$)']-(0.1*df['AnnualSalary(k$)' ])

# %%
df
# Out:
#      CustomerID  Gender  Age  AnnualSalary(k$)  Spendings(1-100)  new column
# 0           157    Male   37                78                 1        70.2  \
# 1           159    Male   34                78                 1        70.2
# 2           201  Female   19               137                 1       123.3
# 3             9    Male   64                19                 3        17.1
# 4           202  Female   19               137                 3       123.3
# ..          ...     ...  ...               ...               ...         ...
# 245         247  Female   69               101                97        90.9
# 246          20  Female   35                23                98        20.7
# 247         248  Female   70               103                98        92.7
# 248          12  Female   35                19                99        17.1
# 249         249    Male   70                97                99        87.3
#
#      new column / netsalry
# ...

# %%
df['Gender'].replace(['Male','Female'],[1,2],inplace=True)
df
# Out:
#      CustomerID  Gender  Age  AnnualSalary(k$)  Spendings(1-100)  new column
# 0           157       1   37                78                 1        70.2  \
# 1           159       1   34                78                 1        70.2
# 2           201       2   19               137                 1       123.3
# 3             9       1   64                19                 3        17.1
# 4           202       2   19               137                 3       123.3
# ..          ...     ...  ...               ...               ...         ...
# 245         247       2   69               101                97        90.9
# 246          20       2   35                23                98        20.7
# 247         248       2   70               103                98        92.7
# 248          12       2   35                19                99        17.1
# 249         249       1   70                97                99        87.3
#
#      new column / netsalry
# ...
