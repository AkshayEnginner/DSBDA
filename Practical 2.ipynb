# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Academic_Perfomance.csv')

# %%
df
# Out:
#    Unnamed: 0    Name  Roll  10th  12th  College  Div
# 0           0  Akshay    26  92.0  88.0     86.0    A
# 1           1   Sahil    45  89.0  95.0     56.0    C
# 2           2     Ram    76  78.0  46.0     43.0  NaN
# 3           3    Raju    89   NaN  67.0     40.0    B
# 4           4  Vishal    14  47.0  32.0      NaN    E
# 5           5   Vinay    15  89.0  43.0     87.0    A
# 6           6   Rohan    18  34.0   NaN     76.0    D
# 7           7   Akash    47  56.0  64.0     87.0  NaN

# %%
df.isnull()
# Out:
#    Unnamed: 0   Name   Roll   10th   12th  College    Div
# 0       False  False  False  False  False    False  False
# 1       False  False  False  False  False    False  False
# 2       False  False  False  False  False    False   True
# 3       False  False  False   True  False    False  False
# 4       False  False  False  False  False     True  False
# 5       False  False  False  False  False    False  False
# 6       False  False  False  False   True    False  False
# 7       False  False  False  False  False    False   True

# %%
df['College'].fillna(df['College'].mean(),inplace=True)

# %%
df
# Out:
#    Unnamed: 0    Name  Roll  10th  12th    College  Div
# 0           0  Akshay    26  92.0  88.0  86.000000    A
# 1           1   Sahil    45  89.0  95.0  56.000000    C
# 2           2     Ram    76  78.0  46.0  43.000000  NaN
# 3           3    Raju    89   NaN  67.0  40.000000    B
# 4           4  Vishal    14  47.0  32.0  67.857143    E
# 5           5   Vinay    15  89.0  43.0  87.000000    A
# 6           6   Rohan    18  34.0   NaN  76.000000    D
# 7           7   Akash    47  56.0  64.0  87.000000  NaN

# %%
df['10th'].fillna(df['10th'].mean(),inplace=True)

# %%
df['12th'].fillna(df['12th'].mean(),inplace=True)

# %%
df
# Out:
#    Unnamed: 0    Name  Roll       10th       12th    College  Div
# 0           0  Akshay    26  92.000000  88.000000  86.000000    A
# 1           1   Sahil    45  89.000000  95.000000  56.000000    C
# 2           2     Ram    76  78.000000  46.000000  43.000000  NaN
# 3           3    Raju    89  69.285714  67.000000  40.000000    B
# 4           4  Vishal    14  47.000000  32.000000  67.857143    E
# 5           5   Vinay    15  89.000000  43.000000  87.000000    A
# 6           6   Rohan    18  34.000000  62.142857  76.000000    D
# 7           7   Akash    47  56.000000  64.000000  87.000000  NaN

# %%
df['Div'].fillna('A',inplace=True)

# %%
df
# Out:
#    Unnamed: 0    Name  Roll       10th       12th    College Div
# 0           0  Akshay    26  92.000000  88.000000  86.000000   A
# 1           1   Sahil    45  89.000000  95.000000  56.000000   C
# 2           2     Ram    76  78.000000  46.000000  43.000000   A
# 3           3    Raju    89  69.285714  67.000000  40.000000   B
# 4           4  Vishal    14  47.000000  32.000000  67.857143   E
# 5           5   Vinay    15  89.000000  43.000000  87.000000   A
# 6           6   Rohan    18  34.000000  62.142857  76.000000   D
# 7           7   Akash    47  56.000000  64.000000  87.000000   A

# %%
import seaborn as sns
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        Unnamed: 0       Roll       10th       12th    College
# count     8.00000   8.000000   8.000000   8.000000   8.000000
# mean      3.50000  41.250000  69.285714  62.142857  67.857143
# std       2.44949  28.634395  21.671010  21.748094  19.504055
# min       0.00000  14.000000  34.000000  32.000000  40.000000
# 25%       1.75000  17.250000  53.750000  45.250000  52.750000
# 50%       3.50000  35.500000  73.642857  63.071429  71.928571
# 75%       5.25000  54.250000  89.000000  72.250000  86.250000
# max       7.00000  89.000000  92.000000  95.000000  87.000000

# %%
Q1 = df['10th'].quantile(0.25)
Q3 = df['10th'].quantile(0.75)
Q1,Q3
# Out:
# (53.75, 89.0)

# %%
IQR = Q3 - Q1

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit,upper_limit
# Out:
# (0.875, 141.875)

# %%
df[(df['10th']<lower_limit)|(df['10th']>upper_limit)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df[(df['10th']<lower_limit)|(df['10th']>upper_limit)]
#
# NameError: name 'df' is not defined

# %%
df[df['10th']>lower_limit]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df[df['10th']>lower_limit]
#
# NameError: name 'df' is not defined
